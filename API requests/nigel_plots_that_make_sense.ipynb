# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import statistics

# %%
#cleaning up data
df = pd.read_csv("player_full.csv")
df = df.sort_values('mmr', ascending = False).sort_values('playerid')
bool_series = df['playerid'].duplicated()
df['check'] = bool_series
df = df[df.check == False]
df = df.drop('check',axis=1)
df = df.sort_values("mmr",ascending = False)
df = df[df.mmr < 10000]
df = df[df.mmr != 0]
df = df[df.wins != 'unknown']
df = df[df.losses != 'unknown']
df['wins'] = pd.to_numeric(df['wins'])
df['losses'] = pd.to_numeric(df['losses'])
df['total'] = df['wins'] + df['losses']
df['percentage win'] = df['wins'] / df['total'] * 100

# %%
dh = df[df.total == 1]
dh.head(30)
# Out:
#         Unnamed: 0  playerid          name  realm  region   mmr  \
# 106234      106234   8806698  llllllllllll      1       2  7830
# 209906      209906  11073152  IllIIlIIlIIl      1       1  7350
# 205820      205820   2331025      Scarlett      1       1  6701
# 100584      100584   4246402         yummy      1       2  6436
# 205062      205062   8048386       SpeCial      1       1  6321
# 101859      101859    498165   IIIIIIIIIII      1       2  6251
# 100085      100085   8533798  llllllllllll      1       2  6212
# 100788      100788    332978         KITor      2       2  6107
# 101165      101165   2497204  NightPhoenix      2       2  6104
# 100496      100496   4937072        jheffe      1       2  6103
# 101869      101869   9726462  llllllllllll      1       2  6092
# 101750      101750   2473685         Ricus      1       2  6059
# 205059      205059   7581060        Sasori      1       1  6036
# 99798        99798   2552877          UbiQ      1       2  6032
# 101765      101765    484607     Adonminus      1       2  6029
# 101751      101751   8200736      PeterPan      1       2  6027
# 101653      101653   8862255      TheEagle      1       2  6025
# 100283      100283   7476935       DefMars      1       2  5968
# 101663      101663   8188438        PacMaN      1       2  5963
# 100348      100348   3692501      Vindicta      1       2  5951
# 100102      100102   7284017        MaLiBu      1       2  5941
# 101082      101082   7231014   WelcomeBack      1       2  5920
# 99905        99905   7937617      YEPBENIS      1       2  5917
# 203805      203805  11259049  lIlIlIlIlIlI      1       1  5912
# 100481      100481    293435          Zain      1       2  5893
# 100792      100792   4101761  llllllllllll      1       2  5890
# 100334      100334   5986986           Iba      1       2  5888
# 100290      100290   2104339     Spazymazy      1       2  5887
# 99609        99609   4446766  llllllllllll      1       2  5880
# 100397      100397   8642029  llllllllllll      1       2  5876
#
#                league  wins  losses     race  total  percentage win
# 106234  Grandmaster 1     1       0     ZERG      1           100.0
# 209906  Grandmaster 1     1       0     ZERG      1           100.0
# 205820      Masters 1     1       0     ZERG      1           100.0
# 100584      Masters 1     0       1  PROTOSS      1             0.0
# 205062      Masters 1     1       0   TERRAN      1           100.0
# 101859      Masters 1     0       1   TERRAN      1             0.0
# 100085      Masters 1     1       0  PROTOSS      1           100.0
# 100788      Masters 1     1       0     ZERG      1           100.0
# 101165      Masters 1     1       0  PROTOSS      1           100.0
# 100496      Masters 1     1       0   TERRAN      1           100.0
# 101869      Masters 1     1       0     ZERG      1           100.0
# 101750      Masters 1     0       1   TERRAN      1             0.0
# 205059      Masters 1     0       1     ZERG      1             0.0
# 99798       Masters 1     0       1   TERRAN      1             0.0
# 101765      Masters 1     0       1  PROTOSS      1             0.0
# 101751      Masters 1     1       0  PROTOSS      1           100.0
# 101653      Masters 1     1       0  PROTOSS      1           100.0
# 100283      Masters 1     0       1   TERRAN      1             0.0
# 101663      Masters 1     1       0  PROTOSS      1           100.0
# 100348      Masters 1     0       1  PROTOSS      1             0.0
# 100102      Masters 1     1       0     ZERG      1           100.0
# 101082      Masters 1     0       1   TERRAN      1             0.0
# 99905       Masters 1     0       1  PROTOSS      1             0.0
# 203805      Masters 1     1       0     ZERG      1           100.0
# 100481      Masters 1     0       1  PROTOSS      1             0.0
# 100792      Masters 1     1       0   TERRAN      1           100.0
# 100334      Masters 1     0       1   TERRAN      1             0.0
# 100290      Masters 1     0       1     ZERG      1             0.0
# 99609       Masters 1     0       1     ZERG      1             0.0
# 100397      Masters 1     0       1     ZERG      1             0.0

# %%
df = df[df.wins != 'unknown']
df = df[df.losses != 'unknown']
df['wins'] = pd.to_numeric(df['wins'])
df['losses'] = pd.to_numeric(df['losses'])
df['total'] = df['wins'] + df['losses']
df['percentage win'] = df['wins'] / df['total'] * 100

# %%
#total distribution
dg = df[df.total < 3000].sort_values('total', ascending = True)
#dg = df.sort_values('total', ascending = True)
thelist = dg['total'].tolist()
thedict = {}
for i in range(302):
    thedict[i*10] = 0
for i in thelist:
    j = round(i,-1)
    thedict[j] += 1
names = list(thedict.keys())
for i in thedict:
    if thedict[i] != 0:
        thedict[i] = math.log(thedict[i])
values = list(thedict.values())

plt.bar(range(len(thedict)), values, tick_label=names)
plt.show()

# %%
#lol
dg = df[df.total == 2]
dg
# Out:
#         Unnamed: 0  playerid          name  realm  region   mmr  \
# 106235      106235   8852487  IllIIlllIllI      1       2  7537
# 209907      209907  11124859  IlIIllIIllIl      1       1  7168
# 101168      101168   1459895     PtitDrogo      1       2  6618
# 100078      100078    889358          Lain      2       2  6534
# 205807      205807  11192787   NotABarcode      1       1  6524
# ...            ...       ...           ...    ...     ...   ...
# 169874      169874  10080953  BobTheIntern      1       1  1091
# 166839      166839  11295012   TheArtOfWar      1       1  1077
# 57852        57852   9938365    Rauchtiger      1       2  1056
# 170039      170039  11678415       miguelh      1       1  1048
# 59267        59267   8467991       McLaren      1       2  1028
#
#                league  wins  losses     race  total  percentage win
# 106235  Grandmaster 1     1       1     ZERG      2            50.0
# 209907  Grandmaster 1     1       1     ZERG      2            50.0
# 101168      Masters 1     1       1  PROTOSS      2            50.0
# 100078      Masters 1     1       1  PROTOSS      2            50.0
# 205807      Masters 1     2       0     ZERG      2           100.0
# ...               ...   ...     ...      ...    ...             ...
# 169874       Silver 3     0       2   TERRAN      2             0.0
# 166839       Silver 3     0       2     ZERG      2             0.0
# 57852        Silver 3     1       1  PROTOSS      2            50.0
# 170039       Silver 3     1       1  PROTOSS      2            50.0
# 59267        Silver 3     0       2   TERRAN      2             0.0
#
# [7540 rows x 12 columns]

# %%
#mmr distribution
dg = df.sort_values('mmr', ascending = False)
thelist = dg['mmr'].tolist()
thedict = {}
for i in range(80):
    thedict[i*100] = 0
for i in thelist:
    j = round(i,-2)
    thedict[j] += 1
    
names = list(thedict.keys())
values = list(thedict.values())

plt.bar(range(len(thedict)), values, tick_label=names)
plt.show()
print(thedict)
# Out:
# {0: 0, 100: 0, 200: 2, 300: 1, 400: 1, 500: 0, 600: 4, 700: 5, 800: 4, 900: 12, 1000: 19, 1100: 45, 1200: 115, 1300: 233, 1400: 463, 1500: 822, 1600: 1419, 1700: 2092, 1800: 3145, 1900: 4430, 2000: 5988, 2100: 7242, 2200: 8102, 2300: 8488, 2400: 9261, 2500: 8685, 2600: 8955, 2700: 8771, 2800: 8850, 2900